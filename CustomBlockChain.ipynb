# %% [markdown]
# #Creating a custom (POA) ethereum blockchain
#
# #Enviroment setup instructions and dependencies:
# First we will cd into our "Blockchain-Tools" directory.
# we then create two nodes using the following code and remember to store the addresses for each node and remember your password: ./geth --datadir node3(4) account new.
# then run puppeth (type: ./puppeth)
#
# ![image.png](attachment:6c301b98-f126-400c-b5a7-983cf88bbf76.png)

# %% [markdown]
#  #This will then offer you many prompts to set up the network. To set up a POA, select the following options:
#         #Configure new genesis (option 2)
#         #Create a new genesis from scratch (option 1)
#         #Choose what consensus algorithm to use (POA, option 2)
#         #How many seconds should blocks take (we will be using default so just press enter)
#         #Then we will seal our two accounts so copy and paste the addresses you recorded before
#         #Paste them again to pre fund them
#         #Enter through the next question to pre fund them
#         #Now you must declare the chain-ID, I chose 334
#         #We must now manage the chain so we choose (option 2) to manage existing genisis
#         #Then export genesis configurations (option 2)
#         #And declare where this should be saved, you can delete all files except for the first one that is just .json
# ![image.png](attachment:1234e989-71f1-4ed9-97e2-7e6ad6d7110d.png)

# %% [markdown]
# #we then must initialize each node (second one on another terminal) with that recently create .json file and enable mining and rpc flag for one node.
#     #the example below is for my second node, just remember to change the address.
# """
# ./geth --datadir node4 --unlock "0xC0F8FaBdf5667E06DaDE8228E22558956c727781" --mine --port 30304 --bootnodes
# "enode://f5c537e2d450be2b042699d65ae26bfb8ec7e4976d48d36e7028066b9123b4b03a561636f84f5afd6359ae9d22e88882539d4ca8e0f3bafeddf517094d061c9a@127.0.0.1:30303"
# --ipcdisable --allow-insecure-unlock
# """
#
# ![image.png](attachment:d2f3f6d9-d496-47bc-9564-fd016dd8f73f.png)

# %% [markdown]
# #we are now set up to move onto our wallet, eventually making a transaction.
# #Log into my crypto and create a custom network. make sure you imput the chain id you determined before in the set up.
# ![image.png](attachment:71b3e277-a81a-4872-a6cb-0c7e4fe20897.png)

# %% [markdown]
# #finally you are set up and can transact on your custom blockchain. example below is me sending a transaction from my first node address to my second.
# ![image.png](attachment:be026e72-84f5-43d2-b8cd-27271c675997.png)
